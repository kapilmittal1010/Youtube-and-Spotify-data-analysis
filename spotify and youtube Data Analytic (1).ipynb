# %%
import pandas as pd
import seaborn as sns 
import matplotlib as plt 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Kapil\Downloads\archive (3).zip")

# %%
data
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
data.columns  #show name of data column
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.info     # basic information abou dataset
# Out:
# <bound method DataFrame.info of        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
data.drop(columns = ['Unnamed: 0' , 'Album_type'])
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
# fill the missing value with 0 and 1abs

data['Likes'] = data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes                 0
# Comments              0
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()    #check the count of missing values
# Out:
# Unnamed: 0          0
# Artist              0
# Url_spotify         0
# Track               0
# Album               0
# Album_type          0
# Uri                 0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Url_youtube         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19298 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        19298 non-null  int64
#  1   Artist            19298 non-null  object
#  2   Url_spotify       19298 non-null  object
#  3   Track             19298 non-null  object
#  4   Album             19298 non-null  object
#  5   Album_type        19298 non-null  object
#  6   Uri               19298 non-null  object
#  7   Danceability      19298 non-null  float64
#  8   Energy            19298 non-null  float64
#  9   Key               19298 non-null  float64
#  10  Loudness          19298 non-null  float64
#  11  Speechiness       19298 non-null  float64
#  12  Acousticness      19298 non-null  float64
#  13  Instrumentalness  19298 non-null  float64
#  14  Liveness          19298 non-null  float64
#  15  Valence           19298 non-null  float64
# ...

# %%
# top 10 artist with highest views on Youtube 
data.head(2)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              Track          Album Album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
# ...

# %%
 artist_variable = data.groupby('Artist')['Views'].sum()

# %%
 artist_variable
# Out:
# Artist
# $NOT              1.107849e+08
# $uicideboy$       3.317202e+08
# (G)I-DLE          1.754954e+09
# *NSYNC            1.027833e+09
# 070 Shake         9.609936e+07
#                       ...
# will.i.am         2.830801e+09
# Ángela Aguilar    1.385295e+09
# Ñejo              6.266808e+08
# Ñengo Flow        8.127263e+08
# Øneheart          3.462331e+07
# Name: Views, Length: 2040, dtype: float64

# %%
artist_variable .sort_values(ascending = False)
# Out:
# Artist
# Ed Sheeran          1.546021e+10
# CoComelon           1.460167e+10
# Katy Perry          1.312063e+10
# Charlie Puth        1.216759e+10
# Luis Fonsi          1.162811e+10
#                         ...
# Teufelskicker       3.802800e+04
# Brooks & Dunn       3.324600e+04
# Thomas Karallus     2.519000e+04
# Bibi Blocksberg     2.402000e+04
# Simone & Simaria    8.375000e+03
# Name: Views, Length: 2040, dtype: float64

# %%
 artist_variable .sort_values(ascending = False).head(10)
# Out:
# Artist
# Ed Sheeran                 1.546021e+10
# CoComelon                  1.460167e+10
# Katy Perry                 1.312063e+10
# Charlie Puth               1.216759e+10
# Luis Fonsi                 1.162811e+10
# Justin Bieber              1.099079e+10
# Daddy Yankee               1.086828e+10
# Bruno Mars                 1.023184e+10
# Macklemore & Ryan Lewis    1.012206e+10
# Coldplay                   9.997278e+09
# Name: Views, dtype: float64

# %%
# top 10 track with highest stream on "spotify 
data.head(1)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             Track       Album Album_type  \
# 0  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
#
# [1 rows x 28 columns]

# %%
x = data[['Track','Stream']]
x
# Out:
#                                                Track        Stream
# 0                                     Feel Good Inc.  1.040235e+09
# 1                                    Rhinestone Eyes  3.100837e+08
# 2      New Gold (feat. Tame Impala and Bootie Brown)  6.306347e+07
# 3                                 On Melancholy Hill  4.346636e+08
# 4                                     Clint Eastwood  6.172597e+08
# ...                                              ...           ...
# 20713                           JUST DANCE HARDSTYLE  9.227144e+06
# 20714                 SET FIRE TO THE RAIN HARDSTYLE  1.089818e+07
# 20715                      OUTSIDE HARDSTYLE SPED UP  6.226110e+06
# 20716                            ONLY GIRL HARDSTYLE  6.873961e+06
# 20717                             MISS YOU HARDSTYLE  5.695584e+06
#
# [19298 rows x 2 columns]

# %%
most_stream_Track = x.sort_values(by = ['Stream'], ascending=False).head(10)

# %%
#what are the top most common album type on "spotify and youtube Data Analytic.ipynb"

data.Album_type.unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
 a_type =data['Album_type'].value_counts()
 a_type
# Out:
# Album_type
# album          13952
# single          4653
# compilation      693
# Name: count, dtype: int64

# %%
#how do the average views,likes and comments are compared between different album ttype

data.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df = data.groupby('Album_type')[['Likes','Views','Comments']].mean()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.reset_index()

# %%
df
# Out:
#     Album_type          Likes         Views      Comments
# 0        album  654610.563981  9.842739e+07  28195.258255
# 1  compilation  510876.460836  7.961832e+07  17006.866841
# 2       single  713608.001649  8.269886e+07  27152.191046

# %%
#melt - unpivot a dataframe

df_melted = pd.melt(df, id_vars = 'Album_type', var_name = "Attribute", value_name = 'Total')

# %%
df_melted
# Out:
#     Album_type Attribute         Total
# 0        album     Likes  6.546106e+05
# 1  compilation     Likes  5.108765e+05
# 2       single     Likes  7.136080e+05
# 3        album     Views  9.842739e+07
# 4  compilation     Views  7.961832e+07
# 5       single     Views  8.269886e+07
# 6        album  Comments  2.819526e+04
# 7  compilation  Comments  1.700687e+04
# 8       single  Comments  2.715219e+04

# %%
# draw a bar plot 

plt.figure(figsize = (9,4))

sns.barplot(x = 'Album_type', y = 'Total', hue = 'Attribute', data = df_melted)
plt.show()

# %%
# top 5 toutube channel based on the top 5 channela_type

data.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
c_views=data.groupby('Channel')['Views'].sum().sort_values(ascending = False)

c_views.head(10)
# Out:
# Channel
# T-Series                      4.796159e+10
# LuisFonsiVEVO                 2.170252e+10
# CalvinHarrisVEVO              1.828114e+10
# Macklemore                    1.700341e+10
# Ed Sheeran                    1.691822e+10
# Hear This Music               1.508851e+10
# Cocomelon - Nursery Rhymes    1.460167e+10
# Bruno Mars                    1.301357e+10
# KatyPerryVEVO                 1.247680e+10
# DJSnakeVEVO                   1.245510e+10
# Name: Views, dtype: float64

# %%
type(c_views)
# Out:
# pandas.core.series.Series

# %%
#top most track based on views
data.head(2)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              Track          Album Album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
# ...

# %%
# Out:
#       index                      Channel         Views
# 0         0                     T-Series  4.796159e+10
# 1         1                LuisFonsiVEVO  2.170252e+10
# 2         2             CalvinHarrisVEVO  1.828114e+10
# 3         3                   Macklemore  1.700341e+10
# 4         4                   Ed Sheeran  1.691822e+10
# ...     ...                          ...           ...
# 6709   6709                Giada Coronas  3.100000e+01
# 6710   6710       Christian Rode - Topic  2.800000e+01
# 6711   6711               water Chillon   2.600000e+01
# 6712   6712  Bernhard Kellermann - Topic  8.000000e+00
# 6713   6713    Adi Mira Michaels - Topic  2.000000e+00
#
# [6714 rows x 3 columns]

# %%
data.sort_values(by = 'Views',ascending = False).head(1)
# Out:
#       Unnamed: 0      Artist  \
# 1147        1147  Luis Fonsi
#
#                                             Url_spotify      Track Album  \
# 1147  https://open.spotify.com/artist/4V8Sr092TqfHkf...  Despacito  VIDA
#
#      Album_type                                   Uri  Danceability  Energy  \
# 1147      album  spotify:track:6habFhsOp2NvshLv26DqMb         0.655   0.797
#
#       Key  ...                                  Url_youtube  \
# 1147  2.0  ...  https://www.youtube.com/watch?v=kJQP7kiw5Fk
#
#                                         Title        Channel         Views  \
# 1147  Luis Fonsi - Despacito ft. Daddy Yankee  LuisFonsiVEVO  8.079649e+09
#
#            Likes   Comments  \
# 1147  50788652.0  4252791.0
#
#                                             Description  Licensed  \
# 1147  “Despacito” disponible ya en todas las platafo...      True
#
#      official_video        Stream
# 1147           True  1.506598e+09
#
# [1 rows x 28 columns]

# %%
#which top 7 track have the highest likes to view ratio on youtubeabs
data.head(1)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             Track       Album Album_type  \
# 0  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
#
# [1 rows x 28 columns]

# %%
Track_lv = data[['Likes','Views','Track']]
Track_lv
# Out:
#            Likes        Views                                          Track
# 0      6220896.0  693555221.0                                 Feel Good Inc.
# 1      1079128.0   72011645.0                                Rhinestone Eyes
# 2       282142.0    8435055.0  New Gold (feat. Tame Impala and Bootie Brown)
# 3      1788577.0  211754952.0                             On Melancholy Hill
# 4      6197318.0  618480958.0                                 Clint Eastwood
# ...          ...          ...                                            ...
# 20713     1113.0      71678.0                           JUST DANCE HARDSTYLE
# 20714     2019.0     164741.0                 SET FIRE TO THE RAIN HARDSTYLE
# 20715      329.0      35646.0                      OUTSIDE HARDSTYLE SPED UP
# 20716       88.0       6533.0                            ONLY GIRL HARDSTYLE
# 20717     2484.0     158697.0                             MISS YOU HARDSTYLE
#
# [20718 rows x 3 columns]

# %%
Track_lv['LV_Ratio'] = data['Likes']/data['Views']*100
# Out:
# C:\Users\Kapil\AppData\Local\Temp\ipykernel_8128\4052137464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Track_lv['LV_Ratio'] = data['Likes']/data['Views']*100

# %%
Track_lv
# Out:
#            Likes        Views                                          Track  \
# 0      6220896.0  693555221.0                                 Feel Good Inc.
# 1      1079128.0   72011645.0                                Rhinestone Eyes
# 2       282142.0    8435055.0  New Gold (feat. Tame Impala and Bootie Brown)
# 3      1788577.0  211754952.0                             On Melancholy Hill
# 4      6197318.0  618480958.0                                 Clint Eastwood
# ...          ...          ...                                            ...
# 20713     1113.0      71678.0                           JUST DANCE HARDSTYLE
# 20714     2019.0     164741.0                 SET FIRE TO THE RAIN HARDSTYLE
# 20715      329.0      35646.0                      OUTSIDE HARDSTYLE SPED UP
# 20716       88.0       6533.0                            ONLY GIRL HARDSTYLE
# 20717     2484.0     158697.0                             MISS YOU HARDSTYLE
#
#        LV_Ratio
# 0      0.896958
# ...

# %%
Track_lv.sort_values(by = 'LV_Ratio', ascending = False).head(7)
# Out:
#           Likes      Views                         Track   LV_Ratio
# 19968  237761.0   954081.0                         Intro  24.920421
# 19969  453910.0  1952637.0                   Safety Zone  23.246000
# 19967  250116.0  1180522.0                        Future  21.186899
# 19971  253702.0  1265231.0                 Pandora's Box  20.051832
# 12193       9.0       49.0                     Resistiré  18.367347
# 16297  371437.0  2067753.0  My Universe - Galantis Remix  17.963316
# 15065  188244.0  1054438.0           Burn It (feat. MAX)  17.852543

# %%
#top album having the track with maximum Danceability
t_Danceability=data.groupby('Album')['Danceability'].sum().sort_values(ascending=False)
t_Danceability
# Out:
# Album
# Hamilton (Original Broadway Cast Recording)                                                19.349
# Greatest Hits                                                                              18.463
# Rebelde                                                                                    15.365
# HEROES & VILLAINS                                                                          14.300
# RODZINNY BIZNES                                                                            13.491
#                                                                                             ...
# Relaxing Loopable White Noise                                                               0.000
# You And The Night                                                                           0.000
# Hello, Dolly! (Remastered)                                                                  0.000
# ...

# %%
data[data.Album=='Greatest Hits']
# Out:
#        Unnamed: 0                           Artist  \
# 220           220                             2Pac
# 222           222                             2Pac
# 225           225                             2Pac
# 268           268                    Fleetwood Mac
# 1232         1232                Bruce Springsteen
# 1236         1236                Bruce Springsteen
# 1862         1862                     Shania Twain
# 2164         2164                      Wyclef Jean
# 3079         3079                    Tracy Chapman
# 3097         3097                          Blondie
# 3147         3147                     Willie Colón
# 3578         3578                       Eurythmics
# 3579         3579                       Eurythmics
# 3580         3580                       Eurythmics
# 3598         3598                      Snow Patrol
# 3836         3836                     James Taylor
# 3842         3842                     James Taylor
# ...

# %%
#what is the correlation between Views,Likes,Comments,and Stream  
data.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df_vlcs=data[['Views','Likes','Comments','Stream']]
df_vlcs
# Out:
#              Views      Likes  Comments        Stream
# 0      693555221.0  6220896.0  169907.0  1.040235e+09
# 1       72011645.0  1079128.0   31003.0  3.100837e+08
# 2        8435055.0   282142.0    7399.0  6.306347e+07
# 3      211754952.0  1788577.0   55229.0  4.346636e+08
# 4      618480958.0  6197318.0  155930.0  6.172597e+08
# ...            ...        ...       ...           ...
# 20713      71678.0     1113.0       0.0  9.227144e+06
# 20714     164741.0     2019.0       0.0  1.089818e+07
# 20715      35646.0      329.0       0.0  6.226110e+06
# 20716       6533.0       88.0       0.0  6.873961e+06
# 20717     158697.0     2484.0       0.0  5.695584e+06
#
# [20718 rows x 4 columns]

# %%
df_vlcs.corr()
# Out:
#              Views     Likes  Comments    Stream
# Views     1.000000  0.891101  0.431185  0.601905
# Likes     0.891101  1.000000  0.631670  0.654247
# Comments  0.431185  0.631670  1.000000  0.267737
# Stream    0.601905  0.654247  0.267737  1.000000

# %%
sns.heatmap(df_vlcs.corr())
# Out:
# <Axes: >
